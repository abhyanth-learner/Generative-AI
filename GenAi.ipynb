# %% [markdown]
# OPEN AI

# %%
# %pip install -q -U  openai

# %%
import os
os.environ['OPENAI_API_KEY']="YOUR_API_KEY"

# %%
from openai import OpenAI

client=OpenAI()

response=client.responses.create(
    model="gpt-4o-mini",
    input="Tell me a 2 line  bedtime story"
)
# print(response)
print(response.output[0].content[0].text)

# %%
completion=client.chat.completions.create(
     model="gpt-4o-mini",
     messages=[
         {"role":"system","content":"Yor are a helpfull chat assistant who give short one liners related to machine learning topics any other you just tell me sorry no response"},
         {"role":"user","content":"what is IPL for bcci"}
     ]
)
print(completion.choices[0].message.content)

# %% [markdown]
# GOOGLE GEMINI

# %%
# !pip install -q google-genai

# %%
import os

# %%
os.environ["GEMINI_API_KEY"]="YOUR_API_KEY"

# %%
from google import genai
client =genai.Client()

response= client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Eplain how tokenization in you"
)

print(response.text)

# %%
# Multi dialog conversation

chat=client.chats.create(model="gemini-2.5-flash")

response=chat.send_message("I have total 5 dogs")
print(response.text)
print("-"*100)

response=chat.send_message("how many paws are there in my house")
print(response.text)

# %% [markdown]
# GROQ

# %%
# !pip install -q groq

# %%
import os
from groq import Groq
os.environ["GROQ_API_KEY"]="YOUR_API_KEY"

client=Groq()

chat_completion=client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role":"system","content":"Your are a helpfull assistant who gives 2 line answers"},
        {"role":"user","content":"What is deeplearning?"}
    ]
)

print(chat_completion.choices[0].message.content)
# Out:
# Deep learning is a subset of machine learning that uses neural networks with multiple layers to analyze and interpret complex data, such as images, speech, and text. It's inspired by the structure and function of the human brain, allowing computers to learn and improve their performance on various tasks autonomously.

# %%
client = Groq()

chat_completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "What is Deep Learning?"},
        {"role": "assistant", "content": "Deep learning is a subfield of machine learning that involves the use of artificial neural networks (ANNs) to analyze and interpret data."},
        {"role": "user", "content": "Give some applications."}
    ]
)

print(chat_completion.choices[0].message.content)

# %% [markdown]
# OLLAMA

# %%
# !pip install -q ollama

# %%
# !ollama list
# Out:
# NAME         ID              SIZE      MODIFIED
# gemma3:1b    8648f39daa8f    815 MB    24 hours ago

# %% [markdown]
# LANGCHAIN

# %%
import ollama

response=ollama.chat(
    model="gemma3:1b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "What is Machine Learning?"}
    ]
)

print(response["message"]["content"])

# %%
stream = ollama.chat(
    model="gemma3:1b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant"},
        {"role": "user", "content": "What is Artificial Intelligence?"}
    ],
    stream=True
)

for chunk in stream:
    print(chunk["message"]["content"], end="", flush=True)

# %%
# !pip install -q langchain-community

# %%
# !pip install -q langchain-openai

# %%
import os
from langchain_openai import ChatOpenAI

os.environ['OPENAI_API_KEY']="YOUR_API_KEY"

llm=ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

response =llm.invoke("What is ipl for bcci")

print(response.content)

# %%
# !pip install -q -U langchain-google-genai
import os
from langchain_google_genai import ChatGoogleGenerativeAI


os.environ["GEMINI_API_KEY"]="YOUR_API_KEY"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
)

response = llm.invoke("What is Machine Learning in one line")

print(response.content)

# %%
# !pip install -q -U langchain-groq
import os
from langchain_groq import ChatGroq

os.environ["GEMINI_API_KEY"]="YOUR_API_KEY"
llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0,
)

response = llm.invoke("What is Machine Learning in one line")

print(response.content)
# Out:
# Machine Learning is a subset of Artificial Intelligence that enables systems to automatically learn and improve from data without being explicitly programmed.

# %% [markdown]
# LLAMA INDEX

# %%
# !pip install -q llama-index

# %%
# !pip install -q -U llama-index-llms-openai

# %%
import os
os.environ['OPENAI_API_KEY']="YOUR_API_KEY"

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(
    model="gpt-3.5-turbo",
    temperature=0.1
)

response = llm.complete("Machine Learning is")

print(response)
# Out:
#  a subset of artificial intelligence that involves the development of algorithms and statistical models that enable computers to learn from and make predictions or decisions based on data without being explicitly programmed. It is used in a wide range of applications, such as image and speech recognition, natural language processing, and recommendation systems. Machine learning algorithms can be categorized into supervised, unsupervised, and reinforcement learning, each with its own set of techniques and approaches.

# %%
from llama_index.llms.openai import OpenAI
from llama_index.core.llms import ChatMessage

llm = OpenAI(
    model="gpt-3.5-turbo",
    temperature=0.1
)

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="What is your name"),
]
response = llm.chat(messages)

print(response)
# Out:
# assistant: Ahoy matey! The name's Captain Rainbowbeard! Aye, I be a pirate with a love for all things colorful and bright, from me rainbow-hued beard to me vibrant sails billowing in the wind. What can I do for ye today, me hearty?
